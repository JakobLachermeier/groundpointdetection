# %%
from groundpoint_estimators.utils import get_gradient_boosting_regressor_with_pipeline, get_ridge_regressor_with_pipeline
import numpy as np

# %%
ridge, ridge_pipeline = get_ridge_regressor_with_pipeline()
# Out:
# got standardscaler with mean: [0.34355657 0.46077598 0.33172874 0.48388786 0.3117259  0.49393719
#  0.30426501 0.49609042 0.2982396  0.49295898 0.29224331 0.49076534
#  0.28739035 0.4782788  0.29157017 0.47102202 0.29081544 0.4633364
#  0.29094985 0.45888649 0.29598516 0.45319547 0.29516209 0.44768907
#  0.29829988 0.44434979 0.30164241 0.43862262 0.30121764 0.43690496
#  0.30470234 0.43779179 0.30359051 0.43965839 0.30351139 0.44283775
#  0.30388966 0.44743682 0.30049349 0.44840523 0.29977172 0.44852836
#  0.29999898 0.44951573 0.30017023 0.45065863 0.30002043 0.45173874
#  0.30051495 0.45267136 0.30027706 0.45334913 0.29925561 0.4540453
#  0.2993604  0.45374945 0.2991478  0.45402589 0.29943161 0.45455724
#  0.29968862 0.45426256 0.30018372 0.45452032 0.29988059 0.45586568
#  0.29978225 0.45569452 0.29964727 0.4552835  0.29955553 0.4543019
#  0.29924823 0.45495687 0.29894734 0.45553526 0.29959494 0.45538853
#  0.29925784 0.45695756 0.29892239 0.45705973 0.29921819 0.45627485
# ...

# %%
gbr, gbr_pipeline = get_gradient_boosting_regressor_with_pipeline()

# %%
hulls = np.random.rand(100, 28, 2)

# %%
processed = ridge_pipeline.transform(hulls) # -> shape: (100, 200)
predictions = ridge.predict(processed) # -> shape: (100, 2)

# %%
# Out:
# (100, 2)
