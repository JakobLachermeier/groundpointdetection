# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial import ConvexHull

# %%
with open('output/')
# Out:
# (1080, 1920, 3)

# %%
cars_min = np.array([0, 0, 13])
cars_max = np.array([255, 255, 16])
mask = cv2.inRange(image_seg, cars_min, cars_max)
image_seg[mask == 0] = [0, 0, 0]
mask[0][0]
# Out:
# 0

# %%
plt.imshow(image_seg)

# %%
mask[0][100]
# Out:
# 0

# %%
ids = np.sum(image_seg[:, :, 1:], axis=2)
values, indices, counts = np.unique(ids, return_index=True, return_counts=True)
ids[0][100], values[np.argmax(counts)], ids.shape, ids.dtype, len(counts)
# Out:
# (0, 0, (1080, 1920), dtype('uint64'), 23)

# %%
plt.imshow(ids, cmap='gray')

# %%
hull_points = np.where(ids == values[np.argmax(counts)])
len(hull_points[0])
# Out:
# 1987738

# %%
object_pixels = np.column_stack(hull_points)
hull = ConvexHull(object_pixels)

# %%
plt.plot(object_pixels[hull.vertices,0], object_pixels[hull.vertices,1], 'r--', lw=2)

plt.plot(object_pixels[hull.vertices[0],0], object_pixels[hull.vertices[0],1], 'ro')

plt.show()

# %%
(ids == 122).sum()
# Out:
# 643993

# %%
a = np.array([True, False, True, True]).reshape(2, 2)
a
# Out:
# array([[ True, False],
#        [ True,  True]])

# %%
np.where(a)
# Out:
# (array([0, 1, 1]), array([0, 0, 1]))
